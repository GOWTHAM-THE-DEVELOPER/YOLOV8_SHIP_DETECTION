# %%
# Pip install method (recommended)

# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.9/107.7 GB disk)

# %%
# %cd /content/drive/MyDrive/YOLO
# Out:
# /content/drive/MyDrive/YOLO

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd /content/drive/MyDrive/YOLO

# !yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/YOLO/data.yaml epochs=50 imgsz=640
# Out:
# /content/drive/MyDrive/YOLO
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo detect val model=/content/drive/MyDrive/YOLO/runs/detect/train15/weights/best.pt data=/content/drive/MyDrive/YOLO/data.yaml  # val custom model
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11127906 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/drive/MyDrive/YOLO/data/valid/labels.cache... 1396 images, 0 backgrounds, 0 corrupt: 100% 1396/1396 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 88/88 [20:50<00:00, 14.21s/it]
#                    all       1396       1850      0.978      0.977      0.991      0.846
#     bulk cargo carrier       1396        377      0.969       0.98      0.988      0.867
#         container ship       1396        193      0.996          1      0.995      0.887
#           fishing boat       1396        434      0.961      0.962      0.987      0.782
#     general cargo ship       1396        329      0.979      0.976      0.992      0.854
#            ore carrier       1396        428      0.976      0.969      0.991       0.85
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('/content/drive/MyDrive/YOLO/runs/detect/train15/weights/best.pt')  # pretrained YOLOv8n model

# Run batched inference on a list of images
results = model(['/content/drive/MyDrive/YOLO/data/test/images/003176_jpg.rf.e040d596ff006ae1fb24df4c9c8df879.jpg'])  # return a list of Results objects


# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    result.show()  # display to screen
    result.save(filename='result.jpg')  # save to disk/content/drive/MyDrive/YOLO/data/test/images/003176_jpg.rf.e040d596ff006ae1fb24df4c9c8df879.jpg
# Out:
# 0: 640x640 1 ore carrier, 687.5ms
# Speed: 5.3ms preprocess, 687.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('/content/drive/MyDrive/YOLO/runs/detect/train15/weights/best.pt')

# Run inference on an image
results = model('/content/drive/MyDrive/YOLO/data/test/images/003176_jpg.rf.e040d596ff006ae1fb24df4c9c8df879.jpg')  # results list

# View results

for r in results:
    print(r.boxes)  # print the Boxes object containing the detection bounding boxes
# Out:
# image 1/1 /content/drive/MyDrive/YOLO/data/test/images/003176_jpg.rf.e040d596ff006ae1fb24df4c9c8df879.jpg: 640x640 1 ore carrier, 860.8ms
# Speed: 2.5ms preprocess, 860.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([4.])
# conf: tensor([0.9042])
# data: tensor([[4.8950e-02, 2.2148e+02, 3.8207e+02, 3.2033e+02, 9.0418e-01, 4.0000e+00]])
# id: None
# is_track: False
# orig_shape: (640, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[191.0617, 270.9037, 382.0255,  98.8525]])
# xywhn: tensor([[0.2985, 0.4233, 0.5969, 0.1545]])
# xyxy: tensor([[4.8950e-02, 2.2148e+02, 3.8207e+02, 3.2033e+02]])
# xyxyn: tensor([[7.6485e-05, 3.4606e-01, 5.9699e-01, 5.0052e-01]])

# %%
# !yolo export model=/content/drive/MyDrive/YOLO/runs/detect/train15/weights/best.pt format=onnx  # export custom trained model
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11127906 parameters, 0 gradients, 28.4 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/YOLO/runs/detect/train15/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 10, 8400) (21.5 MB)
# requirements: Ultralytics requirement ['onnx>=1.12.0'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 172.7 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 12.1s, installed 1 package: ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.16.0 opset 17...
# ONNX: export success ✅ 15.0s, saved as '/content/drive/MyDrive/YOLO/runs/detect/train15/weights/best.onnx' (42.7 MB)
#
# Export complete (18.4s)
# Results saved to /content/drive/MyDrive/YOLO/runs/detect/train15/weights
# ...
